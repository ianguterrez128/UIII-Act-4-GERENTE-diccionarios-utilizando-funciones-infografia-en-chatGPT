# %% [markdown]
# <a href="https://colab.research.google.com/github/ianguterrez128/UIII-Act-4-GERENTE-diccionarios-utilizando-funciones-infografia-en-chatGPT/blob/main/UIII_Act_4_GERENTE_diccionarios_utilizando_funciones_%2B_infografia_en_chatGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Ian gutierrez NL = 22 Fecha 13/may/2026
# ##Educación y Administración
# 22. Gerente: Nivel de autoridad, unidad de negocio, bonos por desempeño, estrategia principal, reuniones diarias y sucursal.

# %%
# ======================================================
# SISTEMA DE GERENTES
# CBTIS 128
# Especialidad: Inteligencia Artificial
# Submodulo 2: Elabora proyectos de programación lógica
# Docente: Eliseo Nava
# Alumno: Ian Josafat Gutierrez Saucedo
# ======================================================

# diccionario vacio
gerentes = []


# ======================================================
# FUNCION AGREGAR
# ======================================================

def agregar_gerente():

    while True:

        nombre = input("ingresa el nombre del gerente: ")
        autoridad = input("ingresa el nivel de autoridad: ")
        unidad = input("ingresa la unidad de negocio: ")
        bonos = input("ingresa bonos por desempeño: ")
        estrategia = input("ingresa la estrategia principal: ")
        reuniones = input("ingresa reuniones diarias: ")
        sucursal = input("ingresa la sucursal: ")

        gerente = {
            "nombre": nombre,
            "autoridad": autoridad,
            "unidad": unidad,
            "bonos": bonos,
            "estrategia": estrategia,
            "reuniones": reuniones,
            "sucursal": sucursal
        }

        gerentes.append(gerente)

        print("\ngerente agregado correctamente")

        respuesta = input("deseas agregar otro gerente? si/no: ")

        if respuesta == "no":
            break


# ======================================================
# FUNCION LISTAR
# ======================================================

def listar_gerentes():

    while True:

        if len(gerentes) == 0:

            print("\nno hay gerentes registrados")

        else:

            print("\n================ TABLA DE GERENTES ================\n")

            print("{:<15} {:<15} {:<20} {:<15} {:<25} {:<15} {:<15}".format(
                "NOMBRE",
                "AUTORIDAD",
                "UNIDAD",
                "BONOS",
                "ESTRATEGIA",
                "REUNIONES",
                "SUCURSAL"
            ))

            print("-" * 130)

            for gerente in gerentes:

                print("{:<15} {:<15} {:<20} {:<15} {:<25} {:<15} {:<15}".format(
                    gerente["nombre"],
                    gerente["autoridad"],
                    gerente["unidad"],
                    gerente["bonos"],
                    gerente["estrategia"],
                    gerente["reuniones"],
                    gerente["sucursal"]
                ))

        respuesta = input("\ndeseas volver a listar? si/no: ")

        if respuesta == "no":
            break


# ======================================================
# FUNCION BUSCAR
# ======================================================

def buscar_gerente():

    while True:

        buscar = input("ingresa el nombre del gerente a buscar: ")

        encontrado = False

        for gerente in gerentes:

            if gerente["nombre"] == buscar:

                print("\n=========== GERENTE ENCONTRADO ===========")
                print("-" * 45)

                for key, value in gerente.items():

                    print(key, ":", value)

                print("-" * 45)

                encontrado = True

        if encontrado == False:

            print("\ngerente no encontrado")

        respuesta = input("\ndeseas buscar otro gerente? si/no: ")

        if respuesta == "no":
            break


# ======================================================
# FUNCION BORRAR
# ======================================================

def borrar_gerente():

    while True:

        borrar = input("ingresa el nombre del gerente a borrar: ")

        encontrado = False

        for gerente in gerentes:

            if gerente["nombre"] == borrar:

                gerentes.remove(gerente)

                print("\ngerente eliminado correctamente")

                encontrado = True

                break

        if encontrado == False:

            print("\ngerente no encontrado")

        respuesta = input("\ndeseas borrar otro gerente? si/no: ")

        if respuesta == "no":
            break


# ======================================================
# FUNCION ACTUALIZAR
# ======================================================

def actualizar_gerente():

    while True:

        buscar = input("ingresa el nombre del gerente a actualizar: ")

        encontrado = False

        for gerente in gerentes:

            if gerente["nombre"] == buscar:

                gerente["nombre"] = input("nuevo nombre: ")
                gerente["autoridad"] = input("nuevo nivel de autoridad: ")
                gerente["unidad"] = input("nueva unidad de negocio: ")
                gerente["bonos"] = input("nuevos bonos por desempeño: ")
                gerente["estrategia"] = input("nueva estrategia principal: ")
                gerente["reuniones"] = input("nuevas reuniones diarias: ")
                gerente["sucursal"] = input("nueva sucursal: ")

                print("\ngerente actualizado correctamente")

                encontrado = True

        if encontrado == False:

            print("\ngerente no encontrado")

        respuesta = input("\ndeseas actualizar otro gerente? si/no: ")

        if respuesta == "no":
            break


# ======================================================
# MENU PRINCIPAL
# ======================================================

while True:

    print("\n================ MENU DE GERENTES ================")
    print("1. agregar gerente en un diccionario")
    print("2. listar diccionarios de gerentes")
    print("3. buscar gerente en diccionario")
    print("4. borrar gerente en diccionario")
    print("5. actualizar gerente en diccionario")
    print("6. salir")

    opcion = int(input("\ningresa una opcion: "))

    if opcion == 1:

        agregar_gerente()

    elif opcion == 2:

        listar_gerentes()

    elif opcion == 3:

        buscar_gerente()

    elif opcion == 4:

        borrar_gerente()

    elif opcion == 5:

        actualizar_gerente()

    elif opcion == 6:

        print("\nfin del programa")
        break

    else:

        print("\nopcion no valida")
# Out:
# ================ MENU DE GERENTES ================
# 1. agregar gerente en un diccionario
# 2. listar diccionarios de gerentes
# 3. buscar gerente en diccionario
# 4. borrar gerente en diccionario
# 5. actualizar gerente en diccionario
# 6. salir
#
# ingresa una opcion: 1
# ingresa el nombre del gerente: nava
# ingresa el nivel de autoridad: alto
# ingresa la unidad de negocio: ventas
# ingresa bonos por desempeño: 15000
# ingresa la estrategia principal: Aumentar clientes
# ingresa reuniones diarias: 3
# ingresa la sucursal: monterrey
#
# gerente agregado correctamente
# deseas agregar otro gerente? si/no: si
# ingresa el nombre del gerente: mark
# ingresa el nivel de autoridad: medio
# ingresa la unidad de negocio: Recursos Humanos
# ingresa bonos por desempeño: 12000
# ingresa la estrategia principal:  Mejorar contratación
# ingresa reuniones diarias: 2
# ingresa la sucursal: guadalajara
#
# gerente agregado correctamente
# deseas agregar otro gerente? si/no: si
# ...

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/ianguterrez128/UIII-Act-4-GERENTE-diccionarios-utilizando-funciones-infografia-en-chatGPT/refs/heads/main/infografiagerente%20ian%20gutierrez.png)
